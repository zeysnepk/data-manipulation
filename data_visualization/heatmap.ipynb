# %% [markdown]
# # 🗺️ Heatmap
# ##### - A heatmap is a data visualization technique that represents values in a matrix as colors.
# ##### - The color intensity corresponds to the magnitude of the values, making it easy to spot patterns, relationships, clusters, or anomalies at a glance.
# ##### - It is especially useful for analyzing correlations between variables or visualizing large numeric tables such as time series.
# ---

# %% [markdown]
# #### » Load and preview the 'flights' dataset

# %%
import seaborn as sns
df = sns.load_dataset("flights").copy()
df.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
df.describe().T
# Out:
#             count         mean         std     min      25%     50%      75%  \
# year        144.0  1954.500000    3.464102  1949.0  1951.75  1954.5  1957.25
# passengers  144.0   280.298611  119.966317   104.0   180.00   265.5   360.50
#
#                max
# year        1960.0
# passengers   622.0

# %%
df.dtypes
# Out:
# year             int64
# month         category
# passengers       int64
# dtype: object

# %% [markdown]
# #### » Pivot the DataFrame so that 'month' values become the index (y-axis) and 'year' values become the columns (x-axis), with 'passengers' as the cell values, creating the structured matrix format required for a heatmap

# %%
df = df.pivot(index="month", columns="year", values="passengers")

# %%
df
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %% [markdown]
# #### » This heatmap visualizes the pivoted DataFrame, where colors represent passenger counts across months (rows) and years (columns), making temporal patterns easy to detect

# %%
sns.heatmap(df)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %% [markdown]
# #### » This heatmap shows passenger counts across months and years with colors and annotates each cell with its exact integer value for clearer interpretation

# %%
sns.heatmap(df, annot=True, fmt="d")
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %% [markdown]
# #### » This heatmap visualizes passenger counts across months and years with colors, annotates each cell with its integer value and adds grid lines (linewidth=.5) to clearly separate the cells

# %%
sns.heatmap(df, annot=True, fmt="d", linewidth=.5)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %% [markdown]
# #### » A heatmap without color bar

# %%
sns.heatmap(df, annot=True, fmt="d", linewidth=.5, cbar=False)
# Out:
# <Axes: xlabel='year', ylabel='month'>
