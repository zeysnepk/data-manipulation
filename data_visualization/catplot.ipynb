# %% [markdown]
# # 🐱 CatPlot
# ##### - A catplot (categorical plot) is a high-level plotting function in seaborn
# ##### - Allows easy visualization of categorical data across different types of plots.
# ##### - It can create strip plots, swarm plots, boxplots, violin plots, bar plots, and count plots depending on the 'kind' parameter (e.g., kind="bar", kind="box", kind="violin").
# ##### - It is useful for visualizing relationships between a categorical variable and one or more numeric variables, and for comparing across multiple subgroups.
# ---

# %% [markdown]
# #### » Import Pandas for data manipulation and create dataframe for 'diamonds' dataset

# %%
import seaborn as sns
dias = sns.load_dataset("diamonds")
df = dias.copy()
df.dtypes
# Out:
# carat       float64
# cut        category
# color      category
# clarity    category
# depth       float64
# table       float64
# price         int64
# x           float64
# y           float64
# z           float64
# dtype: object

# %% [markdown]
# #### » Order categories using CategoricalDtype

# %%
from pandas.api.types import CategoricalDtype
cat = ["Fair", "Good", "Very Good", "Premium", "Ideal"]
df.cut = df.cut.astype(CategoricalDtype(categories=cat, ordered=True))
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %% [markdown]
# #### » This catplot displays the relationship between diamond cut categories and their prices, showing distributions per group using a default strip plot.

# %%
sns.catplot(x="cut", y="price", data=df)

# %% [markdown]
# #### » This catplot shows the distribution of diamond prices across cut categories using violin plots, combining boxplot statistics with a kernel density estimate for each group.

# %%
sns.catplot(x="cut", y="price", data=df,kind="violin")

# %% [markdown]
# #### » This catplot visualizes the distribution of diamond prices across cut categories using boxplots, highlighting medians, quartiles, and potential outliers for each group.

# %%
sns.catplot(x="cut", y="price", data=df,kind="box")

# %% [markdown]
# #### » This catplot displays the average diamond price for each cut category using bar plots, with error bars indicating the standard deviation.

# %%
sns.catplot(x="cut", y="price", data=df,kind="bar")

# %% [markdown]
# #### » This catplot creates a point plot showing the average diamond price for each cut category, separated by color groups with different markers, and includes vertical lines indicating standard deviation

# %%
sns.catplot(x="cut",y="price",hue="color",kind="point",data=df)
