# %% [markdown]
# # 📊 Barplot
# ##### - A barplot is a type of chart that represents data using rectangular bars.
# ##### - The length or height of each bar corresponds to the value it represents.
# ##### - In seaborn, barplot is typically used to show the average (mean) of a numerical variable
# ##### - It is useful for comparing group means and identifying patterns or differences between categories.
# ---

# %% [markdown]
# #### » Load and preview the 'diamonds' dataset

# %%
import seaborn as sns
dias = sns.load_dataset("diamonds")
df = dias.copy()
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %% [markdown]
# #### » Define the desired order of diamond 'cut' categories from lowest to highest quality

# %%
cat_cut = ["Fair", "Good", "Very Good", "Premium", "Ideal"]

# %% [markdown]
# #### » Convert the 'cut' column to an ordered categorical variable

# %%
from pandas.api.types import CategoricalDtype
df.cut = df.cut.astype(CategoricalDtype(categories=cat_cut, ordered=True))

# %%
df["cut"].head(1)
# Out:
# 0    Ideal
# Name: cut, dtype: category
# Categories (5, object): ['Fair' < 'Good' < 'Very Good' < 'Premium' < 'Ideal']

# %%
df["cut"].value_counts()
# Out:
# cut
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: count, dtype: int64

# %% [markdown]
# #### » Plot the counts as a horizontal bar chart for better readability of labels

# %%
df["cut"].value_counts().plot.barh();

# %% [markdown]
# #### » Add a descriptive title to the chart for clarity

# %%
df["cut"].value_counts().plot.barh().set_title("Class Frequencies of 'Cut 'Variable");

# %% [markdown]
# #### » This version simply uses method chaining for cleaner and more readable code

# %%
(df["cut"]
 .value_counts()
 .plot.barh()
 .set_title("Class Frequencies of 'Cut 'Variable"));

# %% [markdown]
# #### » Plot the counts as a vertical bar chart using the seaborn library

# %%
sns.barplot(x="cut", y=df.cut.index, data=df);

# %% [markdown]
# #### » 'hue' adds coloring

# %%
sns.barplot(x="cut", y=df.cut.index, data=df, hue="cut");

# %% [markdown]
# #### » This barplot compares the 'cut' categories against 'price',separated by diamond color where bar heights represent mean values and the black lines show standard deviation.

# %%
sns.barplot(x="cut", y=df.price, data=df, hue="color");

# %% [markdown]
# #### » Calculate the mean diamond price for each combination of cut and color categories to observe the graph above

# %%
df.groupby(["cut","color"],observed=False)["price"].mean()
# Out:
# cut        color
# Ideal      D        2629.094566
#            E        2597.550090
#            F        3374.939362
#            G        3720.706388
#            H        3889.334831
#            I        4451.970377
#            J        4918.186384
# Premium    D        3631.292576
#            E        3538.914420
#            F        4324.890176
#            G        4500.742134
#            H        5216.706780
#            I        5946.180672
#            J        6294.591584
# Very Good  D        3470.467284
#            E        3214.652083
#            F        3778.820240
#            G        3872.753806
#            H        4535.390351
#            I        5255.879568
#            J        5103.513274
# Good       D        3405.382175
#            E        3423.644159
#            F        3495.750275
#            G        4123.482204
#            H        4276.254986
#            I        5078.532567
#            J        4574.172638
# ...
