# %% [markdown]
# # 🦎 Scatter Plot

# %% [markdown]
# #### » Loading and previewing the 'tips' dataset

# %%
import seaborn as sns
df = sns.load_dataset("tips").copy()
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# #### » Creating a basic scatter plot of total bill vs tip

# %%
sns.scatterplot(x=df.total_bill, y=df.tip)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# #### » Scatter plot of total bill vs tip, colored by time of day

# %%
sns.scatterplot(x=df.total_bill, y=df.tip, hue=df.time)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# #### » Scatter plot of total bill vs tip, using color and marker style to show time of day

# %%
sns.scatterplot(x=df.total_bill, y=df.tip, hue=df.time, style=df.time)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# #### » Scatter plot of total bill vs tip, with color by day and marker style by time

# %%
sns.scatterplot(x=df.total_bill, y=df.tip, hue=df.day, style=df.time)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# #### » Scatter plot using color for time of day and marker style for day of week

# %%
sns.scatterplot(x=df.total_bill, y=df.tip, hue=df.time, style=df.day)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# #### » Scatter plot with marker size representing party size

# %%
sns.scatterplot(x=df.total_bill, y=df.tip, size=df["size"])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# #### » Scatter plot where both size and color represent party size

# %%
sns.scatterplot(x=df.total_bill, y=df.tip, size=df["size"], hue=df["size"])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>
