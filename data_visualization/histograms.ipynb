# %% [markdown]
# # 📉 Histogram
# ##### - A histogram is used to display the distribution of a numerical variable by grouping values into bins.
# ##### - The x-axis shows intervals (bins) of the variable, while the y-axis shows the frequency of observations within each bin.
# ##### - It is useful for understanding the shape of the data distribution, detecting skewness, spread, and identifying possible outliers.
# ---

# %% [markdown]
# #### » Create dataframe for 'diamonds' dataset

# %%
import seaborn as sns
diamonds = sns.load_dataset('diamonds')
df = diamonds.copy()
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %% [markdown]
# #### » This histogram displays the distribution of diamond prices by grouping them into bins and showing their frequencies.

# %%
sns.histplot(df.price)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %% [markdown]
# #### » This histogram shows the distribution of diamond prices with bins outlined as step-like lines instead of filled bars.

# %%
sns.histplot(df.price,element="step")
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %% [markdown]
# #### » This histogram visualizes the distribution of diamond prices using 1000 fine-grained bins with step-like outlines for detailed frequency patterns.

# %%
sns.histplot(df.price,element="step",bins=1000)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %% [markdown]
# #### » This histogram displays the distribution of diamond prices using 10 wide bins with step-like outlines, giving a coarse view of frequency patterns.

# %%
sns.histplot(df.price,element="step",bins=10)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %% [markdown]
# #### » This histogram shows the distribution of diamond prices with step-like outlines and overlays a KDE curve to estimate the probability density.

# %%
sns.histplot(df.price,element="step",kde=True)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %% [markdown]
# #### » This KDE plot estimates and visualizes the probability density of diamond prices as a smooth continuous curve.

# %%
sns.kdeplot(df.price);

# %% [markdown]
# #### » This KDE plot shows the estimated probability density of diamond prices as a smooth curve with the area under the curve filled.

# %%
sns.kdeplot(df.price, fill=True)
# Out:
# <Axes: xlabel='price', ylabel='Density'>

# %% [markdown]
# #### » Use FacetGrid to overlay filled KDE curves of 'price' for each 'cut' level (hue), limit x to 0–10000, and add a legend
# ##### ! Crossing all categories ensures that every cut appears in the legend with consistent colors, making the plot useful for detecting differences in spread, skewness, and overall distribution patterns.

# %%
(sns
 .FacetGrid(df,
               hue="cut",
               height=5,
               xlim=(0,10000))
 .map(sns.kdeplot, "price", fill=True)
 .add_legend());
