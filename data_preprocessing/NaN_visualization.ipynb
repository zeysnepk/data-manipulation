# %% [markdown]
# # 🏞️ Visualizing NaN Values

# %% [markdown]
# #### » Create a dataframe containing NaN values

# %%
import numpy as np
import pandas as pd
vector1 = np.array([5,3,6,np.nan,7,2,8,np.nan,4,np.nan])
vector2 = np.array([10,1,5,3,2,8,np.nan,6,np.nan,np.nan])
vector3 = np.array([np.nan,7,6,np.nan,7,np.nan,9,np.nan,1,np.nan])
df = pd.DataFrame({"V1":vector1,"V2":vector2,"V3":vector3})
df
# Out:
#     V1    V2   V3
# 0  5.0  10.0  NaN
# 1  3.0   1.0  7.0
# 2  6.0   5.0  6.0
# 3  NaN   3.0  NaN
# 4  7.0   2.0  7.0
# 5  2.0   8.0  NaN
# 6  8.0   NaN  9.0
# 7  NaN   6.0  NaN
# 8  4.0   NaN  1.0
# 9  NaN   NaN  NaN

# %% [markdown]
# #### » Import "msno" to visualize NaN values and their ratio

# %%
import missingno as msno
msno.bar(df)
# Out:
# <Axes: >

# %% [markdown]
# The right bar of the graph shows values, while the left bar shows ratios. The bars represent actual values, while the gaps represent nan values.

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %% [markdown]
# The curve on the right shows the number of columns that do not contain NaN values in that row.

# %%
import seaborn as sns
planets = sns.load_dataset("planets")
planets.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
planets.isnull().sum()
# Out:
# method              0
# number              0
# orbital_period     43
# mass              522
# distance          227
# year                0
# dtype: int64

# %%
msno.matrix(planets)
# Out:
# <Axes: >

# %% [markdown]
# Before correcting NaN values, we should check if there is a relationship between them to violate any error in the dataset.

# %%
msno.heatmap(planets)
# Out:
# <Axes: >

# %% [markdown]
# We can use the heatmap to check whether mass and distance are correlated. In principle, there should not be a strong correlation, since distance from Earth is independent of a planet’s mass. However, missing values (NaNs) can distort correlation coefficients, so any observed relationship might be an artifact of incomplete data rather than a true dependency.
